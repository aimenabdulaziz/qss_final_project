# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
import random
from plotnine import *

# repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# datetime 
from datetime import timedelta, date, datetime
from dateutil.relativedelta import relativedelta

# %% [markdown]
# # Load the raw data
#
# We are only loading the excel sheets we will use for our research purposes. The sheets we need are `Demographics`, `Presenting Problems`, `Emergency Crisis Services`.

# %%
# Read selected excel sheets into pandas dataframes and save in a dictionary
file_path = '../input/Dartmouth Data Set.xlsx'
sheet_names = ['Demographics', 'Presenting Problems', 'Emergency Crisis Services', 'living Situation change', 'In-patient admissions']

# create an empty dictionary to store the sheet data
sheet_data = {}

# loop through each sheet name and read the corresponding sheet data into a pandas dataframe
for sheet_name in sheet_names:
    sheet_data[sheet_name] = pd.read_excel(file_path, sheet_name)

# %% [markdown]
# # Save the data in variables and inspect them

# %%
# Retrieve the dataframes from the dictionary and save them in variables
demographics = sheet_data['Demographics']
presenting_problems = sheet_data['Presenting Problems']
emergency_crisis_services = sheet_data['Emergency Crisis Services']
living_situation_change = sheet_data['living Situation change']
in_patient_admissions = sheet_data['In-patient admissions']

# %%
# Explore the demographics dataframe
demographics.head()
demographics.columns
demographics.info()
# Out:
#   Local ID                             Region        County  \
# 0  8085297     California : CA START East Bay  Contra Costa
# 1   440987                New York : Region 3      Saratoga
# 2  8008815     California : CA START East Bay       Alameda
# 3   220396                New York : Region 3        Albany
# 4  6570649  California : CA START San Andreas    Santa Cruz
#
#      Start Coordinator Date Enrolled in START  \
# 0        Mary Akhuetie             2020-12-30
# 1      Natalia Wolosen             2020-12-29
# 2  Sharon Cyrus-Savary             2020-12-29
# 3      Matthew Wolcott             2020-12-29
# 4        Ilian Navarro             2020-12-29
#
#                                      Status Status Date  \
# 0                                    Active  2020-12-30
# 1             Inactive (stable functioning)  2021-08-09
# 2  Inactive (no longer requesting services)  2021-06-27
# 3     Inactive (inappropriate for services)  2021-06-11
# 4                                    Active  2020-12-29
#
#                        Time Enrolled in START  \
# 0  Business Hours (Monday - Friday 8am - 5pm)
# 1  Business Hours (Monday - Friday 8am - 5pm)
# 2  Business Hours (Monday - Friday 8am - 5pm)
# 3  Business Hours (Monday - Friday 8am - 5pm)
# 4  Business Hours (Monday - Friday 8am - 5pm)
#
#         Source of referral to START Suitability of enrollment in START  ...  \
# 0  Case Manager/Service Coordinator                        Appropriate  ...
# 1  Case Manager/Service Coordinator                        Appropriate  ...
# 2  Case Manager/Service Coordinator                        Appropriate  ...
# 3  Case Manager/Service Coordinator                        Appropriate  ...
# 4  Case Manager/Service Coordinator                        Appropriate  ...
#
#   State sponsored ICF/DD stay in past 1 - 5 years (at enrollment to START)  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Jailed in the past year (at enrollment to START)  \
# 0                                               No
# 1                                               No
# 2                                               No
# 3                                               No
# 4                                               No
#
#   Jailed in the past 1 - 5 years (at enrollment to START)  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Employment Status at Enrollment Grade In School      Current IEP  \
# 0                         Student         Grade 7  Yes: 2020-11-16
# 1                         Student        Grade 11               No
# 2                         Student         Grade 8  Yes: 2020-01-01
# 3                    Not employed             NaN              NaN
# 4                             NaN             NaN              NaN
#
#   Current 504 Plan                                School Setting  \
# 0               No                Special school-out of district
# 1               No                            Other: BOCES 4:1:2
# 2               No                    Special school-in district
# 3              NaN                                           NaN
# 4              NaN  Other: COE Program Held at Cabrillo College
#
#      Custody Status Child Lives With
# 0  Parental custody          Parents
# 1  Parental custody          Parents
# 2  Parental custody          Parents
# 3               NaN              NaN
# 4               NaN              NaN
#
# [5 rows x 48 columns]
# Index(['Local ID', 'Region', 'County', 'Start Coordinator',
#        'Date Enrolled in START', 'Status', 'Status Date',
#        'Time Enrolled in START', 'Source of referral to START',
#        'Suitability of enrollment in START',
#        'Individual/Caregiver reliable access to technology',
#        'Presenting problems at time of enrollment', 'Services at Enrollment',
#        'Date of birth', 'Gender', 'Race', 'Ethnicity',
#        'Level of Intellectual Disability',
#        'Current living situation at enrollment to START',
#        'More than one living situation over the last 5 years?',
#        'More than one living situation over the last year?',
#        'Psychiatric hospitalization in past year (at enrollment to START)',
#        'Psychiatric hospitalizations in past 1 - 5 years (at enrollment to START)',
#        'Emergency department visits in past year (at enrollment to START)',
#        'Emergency department visits in past 1-5 years (at enrollment to START)',
#        'Law enforcement encounters in past year (at enrollment to START)',
#        'Law enforcement encounters in past 1 - 5 years (at enrollment to START)',
#        'Psychiatric diagnoses', 'Medical diagnoses', 'Other Disabilities',
#        'Cause/etiology of disability',
#        'Who is the individual's primary caregiver?',
#        'Does the individual have a secondary caregiver?',
#        'Does the individual have a legal guardian?', 'Funding',
#        'History of Child Protective Services involvement in past year (at enrollment to START)',
#        'History of Child Protective Services involvement in lifetime (at enrollment to START)',
#        'State sponsored ICF/DD stay in past year (at enrollment to START)',
#        'State sponsored ICF/DD stay in past 1 - 5 years (at enrollment to START)',
#        'Jailed in the past year (at enrollment to START)',
#        'Jailed in the past 1 - 5 years (at enrollment to START)',
#        'Employment Status at Enrollment', 'Grade In School', 'Current IEP',
#        'Current 504 Plan', 'School Setting', 'Custody Status',
#        'Child Lives With'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4986 entries, 0 to 4985
# Data columns (total 48 columns):
#  #   Column                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                  --------------  -----
#  0   Local ID                                                                                4986 non-null   object
#  1   Region                                                                                  4986 non-null   object
#  2   County                                                                                  4986 non-null   object
#  3   Start Coordinator                                                                       4947 non-null   object
#  4   Date Enrolled in START                                                                  4986 non-null   datetime64[ns]
#  5   Status                                                                                  4986 non-null   object
#  6   Status Date                                                                             4986 non-null   datetime64[ns]
#  7   Time Enrolled in START                                                                  4893 non-null   object
#  8   Source of referral to START                                                             4964 non-null   object
#  9   Suitability of enrollment in START                                                      4986 non-null   object
#  10  Individual/Caregiver reliable access to technology                                      863 non-null    object
#  11  Presenting problems at time of enrollment                                               4958 non-null   object
#  12  Services at Enrollment                                                                  4899 non-null   object
#  13  Date of birth                                                                           4986 non-null   datetime64[ns]
#  14  Gender                                                                                  4986 non-null   object
#  15  Race                                                                                    4986 non-null   object
#  16  Ethnicity                                                                               4986 non-null   object
#  17  Level of Intellectual Disability                                                        4985 non-null   object
#  18  Current living situation at enrollment to START                                         4986 non-null   object
#  19  More than one living situation over the last 5 years?                                   4986 non-null   object
#  20  More than one living situation over the last year?                                      4023 non-null   object
#  21  Psychiatric hospitalization in past year (at enrollment to START)                       4871 non-null   object
#  22  Psychiatric hospitalizations in past 1 - 5 years (at enrollment to START)               4850 non-null   object
#  23  Emergency department visits in past year (at enrollment to START)                       4859 non-null   object
#  24  Emergency department visits in past 1-5 years (at enrollment to START)                  4843 non-null   object
#  25  Law enforcement encounters in past year (at enrollment to START)                        29 non-null     object
#  26  Law enforcement encounters in past 1 - 5 years (at enrollment to START)                 29 non-null     object
#  27  Psychiatric diagnoses                                                                   4615 non-null   object
#  28  Medical diagnoses                                                                       3171 non-null   object
#  29  Other Disabilities                                                                      910 non-null    object
#  30  Cause/etiology of disability                                                            964 non-null    object
#  31  Who is the individual's primary caregiver?                                              4857 non-null   object
#  32  Does the individual have a secondary caregiver?                                         4986 non-null   object
#  33  Does the individual have a legal guardian?                                              4986 non-null   object
#  34  Funding                                                                                 4904 non-null   object
#  35  History of Child Protective Services involvement in past year (at enrollment to START)  4986 non-null   object
#  36  History of Child Protective Services involvement in lifetime (at enrollment to START)   4986 non-null   object
#  37  State sponsored ICF/DD stay in past year (at enrollment to START)                       4986 non-null   object
#  38  State sponsored ICF/DD stay in past 1 - 5 years (at enrollment to START)                4986 non-null   object
#  39  Jailed in the past year (at enrollment to START)                                        4986 non-null   object
#  40  Jailed in the past 1 - 5 years (at enrollment to START)                                 4986 non-null   object
#  41  Employment Status at Enrollment                                                         4750 non-null   object
#  42  Grade In School                                                                         2803 non-null   object
#  43  Current IEP                                                                             3669 non-null   object
#  44  Current 504 Plan                                                                        3379 non-null   object
#  45  School Setting                                                                          2068 non-null   object
#  46  Custody Status                                                                          2339 non-null   object
#  47  Child Lives With                                                                        2612 non-null   object
# dtypes: datetime64[ns](3), object(45)
# memory usage: 1.8+ MB

# %%
# Explore the emergency crisis services dataframe
emergency_crisis_services.head()
emergency_crisis_services.columns
emergency_crisis_services.info()
# Out:
#   Individual ID                                         Region  \
# 0      11153125  New Hampshire : Region 2 - Pathways/Claremont
# 1      11153125  New Hampshire : Region 2 - Pathways/Claremont
# 2      11153125  New Hampshire : Region 2 - Pathways/Claremont
# 3      11158347  New Hampshire : Region 9 - Community Partners
# 4      11158347  New Hampshire : Region 9 - Community Partners
#
#   Date/Time of Contact                 Source of Contact  \
# 0  2016-08-16 08:40:00  Case Manager/Service Coordinator
# 1  2018-04-27 15:00:00  Case Manager/Service Coordinator
# 2  2018-06-05 16:00:00  Residential provider - Community
# 3  2015-06-01 14:00:00                     Family member
# 4  2015-06-01 16:00:00                     Family member
#
#                                   Reason for Contact  \
# 0  At risk of losing placement, Other, Self-injur...
# 1             Mental health symptoms, Self-injurious
# 2  Mental health symptoms, Suicidal ideation/beha...
# 3  Diagnosis and treatment plan assistance, Other...
# 4  Aggression (physical, verbal, property destruc...
#
#   Type of Emergency Response  \
# 0    Phone consultation only
# 1  In-person: Emergency room
# 2     Other: phone and email
# 3    Phone consultation only
# 4    Phone consultation only
#
#    Total episode length (initial call to disposition)  \
# 0                                               15.0
# 1                                               60.0
# 2                                              120.0
# 3                                              254.0
# 4                                               70.0
#
#    Total response time (initial call to arrival on-site)  Travel Time  \
# 0                                                NaN              NaN
# 1                                              240.0             60.0
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#   Police Response  ... Restraints Used If Restraints Were Used  \
# 0              No  ...              No                     NaN
# 1              No  ...              No                     NaN
# 2              No  ...              No                     NaN
# 3              No  ...              No                     NaN
# 4              No  ...              No                     NaN
#
#                                  Disposition  \
# 0                  Other: outpatient MH appt
# 1  START emergency resource center admission
# 2             Psychiatric Hospital Admission
# 3  START emergency resource center admission
# 4                   Maintain current setting
#
#             Disposition Information Admitted through ED/CPEP  \
# 0                               NaN                       No
# 1                               NaN                       No
# 2                               NaN                       No
# 3                               NaN                       No
# 4  Planned Resource Center referral                       No
#
#   Date of Admission Disposition Information (ER)  \
# 0               NaT                          NaN
# 1               NaT                          NaN
# 2               NaT                          NaN
# 3               NaT                          NaN
# 4               NaT                          NaN
#
#   Did START response prevent higher level of care (hospital diversion)  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   RSQ Completed?         Entered By
# 0             No  Valarie Tetreault
# 1             No   Samantha L Field
# 2             No   Samantha L Field
# 3             No  Valarie Tetreault
# 4             No  Valarie Tetreault
#
# [5 rows x 24 columns]
# Index(['Individual ID', 'Region', 'Date/Time of Contact', 'Source of Contact',
#        'Reason for Contact', 'Type of Emergency Response',
#        'Total episode length (initial call to disposition)',
#        'Total response time (initial call to arrival on-site)', 'Travel Time',
#        'Police Response', 'If Police Responded', 'Who Contacted Police?',
#        'Mobile Crisis', 'If Mobile Crisis', 'Restraints Used',
#        'If Restraints Were Used', 'Disposition', 'Disposition Information',
#        'Admitted through ED/CPEP', 'Date of Admission',
#        'Disposition Information (ER)',
#        'Did START response prevent higher level of care (hospital diversion)',
#        'RSQ Completed?', 'Entered By'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18168 entries, 0 to 18167
# Data columns (total 24 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Individual ID                                                         18168 non-null  object
#  1   Region                                                                18168 non-null  object
#  2   Date/Time of Contact                                                  18168 non-null  datetime64[ns]
#  3   Source of Contact                                                     17780 non-null  object
#  4   Reason for Contact                                                    17983 non-null  object
#  5   Type of Emergency Response                                            17930 non-null  object
#  6   Total episode length (initial call to disposition)                    17106 non-null  float64
#  7   Total response time (initial call to arrival on-site)                 6722 non-null   float64
#  8   Travel Time                                                           6448 non-null   float64
#  9   Police Response                                                       18168 non-null  object
#  10  If Police Responded                                                   2735 non-null   object
#  11  Who Contacted Police?                                                 1950 non-null   object
#  12  Mobile Crisis                                                         18168 non-null  object
#  13  If Mobile Crisis                                                      443 non-null    object
#  14  Restraints Used                                                       18168 non-null  object
#  15  If Restraints Were Used                                               649 non-null    object
#  16  Disposition                                                           17907 non-null  object
#  17  Disposition Information                                               7428 non-null   object
#  18  Admitted through ED/CPEP                                              18168 non-null  object
#  19  Date of Admission                                                     380 non-null    datetime64[ns]
#  20  Disposition Information (ER)                                          1616 non-null   object
#  21  Did START response prevent higher level of care (hospital diversion)  18168 non-null  object
#  22  RSQ Completed?                                                        18168 non-null  object
#  23  Entered By                                                            18168 non-null  object
# dtypes: datetime64[ns](2), float64(3), object(19)
# memory usage: 3.3+ MB

# %%
# Explore the presenting problems dataframe
presenting_problems.head()
presenting_problems.columns
presenting_problems.info()
# Out:
#   Client Local Id START Coordinator                         Region  \
# 0               1     Ashley Gruver  Iowa : County Social Services
# 1               1     Ashley Gruver  Iowa : County Social Services
# 2               1     Ashley Gruver  Iowa : County Social Services
# 3         000083W          Amy Huff          North Carolina : West
# 4         000083W          Amy Huff          North Carolina : West
#
#                    Presenting Problems at Enrollment
# 0  Aggression (physical, verbal, property destruc...
# 1                             Mental health symptoms
# 2                                    Self-injurious
# 3  Aggression (physical, verbal, property destruc...
# 4  Decrease in ability to participate in daily fu...
# Index(['Client Local Id', 'START Coordinator', 'Region',
#        'Presenting Problems at Enrollment'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31014 entries, 0 to 31013
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Client Local Id                    31014 non-null  object
#  1   START Coordinator                  29435 non-null  object
#  2   Region                             31014 non-null  object
#  3   Presenting Problems at Enrollment  31014 non-null  object
# dtypes: object(4)
# memory usage: 969.3+ KB

# %% [markdown]
# Let's skim `Presenting Problems at Enrollment` to see the presented problems

# %%
random.choices(presenting_problems['Presenting Problems at Enrollment'].unique(), k = 20)
# Out:
# ["Other: Urinates on other's belongings",
#  'Other: Medical-Recent Seizures',
#  'Other: legal involvement, substance abuse',
#  'Other: In need of vendor services',
#  'Other: Lack of available supports',
#  'Other: David is part of other residentsÂ¿Â¿Â¿ system. Analyzing how to best support all housemates.',
#  'Other: Not attending school for the last 7 months',
#  'Other: Trauma, family dynamics',
#  'Other: yelling, ocd around food',
#  'Other: Making false statement',
#  'Other: Transition from Developmental Center 9/4/2020',
#  'Other: apic',
#  'Other: At risk sexual behaviors and contact with strangers',
#  'Other: picking at sores on body and washing them with toilet water',
#  'Other: History of elopement from residence where she currently resides',
#  'Other: Refuses to go to school',
#  'Other: unsafe behavior with in the car',
#  'Other: Feces smearing, disrobing in public, urinary incontinence',
#  'Other: transiton from Murdoch',
#  'Other: Purposeful Ingestion and eloping']

# %% [markdown]
# <font color = "green"> As we can see above the presented problems are all over the place. In the next section, we will focus on cleaning this column using regex to narrow down the presented problems.  </font>

# %% [markdown]
# # Data cleaning/preprocessing

# %% [markdown]
# Let's first `Presenting Problems at Enrollment` column to `presented_problems` for more readability.

# %%
# rename the column
presenting_problems.rename(columns={'Presenting Problems at Enrollment': 'presented_problems'}, inplace=True)

# confirm that the column was renamed successfully
presenting_problems.columns
# Out:
# Index(['Client Local Id', 'START Coordinator', 'Region', 'presented_problems'], dtype='object')

# %%
presenting_problems['presented_problems'].value_counts()
# Out:
# Aggression (physical, verbal, property destruction, threats)                                                                                        7427
# Family needs assistance                                                                                                                             4489
# Mental health symptoms                                                                                                                              4356
# Self-injurious                                                                                                                                      2640
# Diagnosis and treatment plan assistance                                                                                                             2246
#                                                                                                                                                     ...
# Other: Social Skills                                                                                                                                   1
# Other: over-eating                                                                                                                                     1
# Other: Individual will claim he has seizures to go to the hospital, although he does not have a history of any seizure activity and/or seizures.       1
# Other: Lack of paid and natural supports                                                                                                               1
# Other: High utilization of Emergency Services                                                                                                          1
# Name: presented_problems, Length: 734, dtype: int64

# %% [markdown]
# Now, let's turn all the presenting problems in lowercase to see add consistency.

# %%
presenting_problems['presented_problems'] = presenting_problems['presented_problems'].str.lower()
presenting_problems.sample(2)
# Out:
#       Client Local Id     START Coordinator                          Region  \
# 28509         8085110          Yakira Evans  California : CA START East Bay
# 12135         291371C  Vonda Jenkins-Kimrey           North Carolina : West
#
#                 presented_problems
# 28509  at risk of losing placement
# 12135  at risk of losing placement

# %%
# subset to rows that do not contain 'other:' for presented problems
presenting_problems_no_other = presenting_problems[~presenting_problems["presented_problems"].str.contains('other:')].copy()
presenting_problems_no_other.presented_problems.unique()

presenting_problems_no_other.shape[0]

print(f"The number of unique presenting problems before dropping 'Other' is: {presenting_problems.presented_problems.nunique()}")
print(f"The number of unique presenting problems is: {presenting_problems_no_other.presented_problems.nunique()}")
# Out:
# array(['aggression (physical, verbal, property destruction, threats)',
#        'mental health symptoms', 'self-injurious ',
#        'decrease in ability to participate in daily functions',
#        'leaving unexpectedly', 'diagnosis and treatment plan assistance',
#        'family needs assistance', 'at risk of losing placement',
#        'sexualized behavior', 'suicidal ideation',
#        'transition from hospital', 'suicidal action'], dtype=object)
# 30011
# The number of unique presenting problems before dropping 'Other' is: 704
# The number of unique presenting problems is: 12

# %% [markdown]
# Let's see how many rows we are losing by removing presented problems that start with `Other:`

# %%
print(f"Retention Rate After Dropping 'Other': {round(100*presenting_problems_no_other.shape[0]/presenting_problems.shape[0], 2)}%")
# Out:
# Retention Rate After Dropping 'Other': 96.77%

# %% [markdown]
# A retention rate of 96.77% is really good, so we will stick with the 12 unique presented problems. Now, we will write a function to parse the `Region` variable to `state` and `region`

# %%
def parse_region(row):
    """
    Parse a string in the format "<state>: <region>" and return a tuple
    containing the state and region.
    
    Parameters:
    row (str): A string in the format "<state> : <region>".
    
    Returns:
    A tuple containing the parsed state and region.
    """
    state, region = row.lower().split(':')
    return state.strip(), region.strip()

# apply the function on the demographics, presenting_problems_no_other, and emergency_crisis_services dataframes
presenting_problems_no_other.loc[:, ['state', 'region_new']] = presenting_problems_no_other['Region'].apply(parse_region).tolist()
demographics.loc[:, ['state', 'region_new']] = demographics['Region'].apply(parse_region).tolist()
emergency_crisis_services.loc[:, ['state', 'region_new']] = emergency_crisis_services['Region'].apply(parse_region).tolist()

# sample from the presenting_problems_no_other dataframe
presenting_problems_no_other.sample(3)
# Out:
#       Client Local Id START Coordinator                           Region  \
# 25500         6252855     Natalie David  California : CA START San Diego
# 30304         932875C     Felix Pittman         North Carolina : Central
# 21131         426466W    Connetta Terry            North Carolina : West
#
#                                       presented_problems           state  \
# 25500  decrease in ability to participate in daily fu...      california
# 30304  aggression (physical, verbal, property destruc...  north carolina
# 21131                            family needs assistance  north carolina
#
#                region_new
# 25500  ca start san diego
# 30304             central
# 21131                west

# %%
# check all the unique states in the presenting_problems_no_other dataframe
presenting_problems_no_other.state.unique()
# Out:
# array(['iowa', 'north carolina', 'texas', 'new york', 'california',
#        'colorado', 'new hampshire', 'maryland'], dtype=object)

# %% [markdown]
# Next, we will merge the `demographic` and `presenting_problems_no_other` dataframes using the `Client ID`.

# %%
demographics_problems_merged = presenting_problems_no_other.merge(demographics, left_on='Client Local Id', right_on='Local ID',
                                                                  how='inner', suffixes=('_presenting_problems', '_demographics'), 
                                                                  indicator = True).drop_duplicates()

# %%
demographics_problems_merged.sample(3)
demographics_problems_merged.shape
# Out:
#      Client Local Id    START Coordinator  \
# 4184         193580W          Hunter Ross
# 9508          372403  Danielle Seivwright
# 6128          285266         Monica Yepes
#
#                        Region_presenting_problems  \
# 4184                        North Carolina : West
# 9508  New York : Region 4 Tri-Borough - The Bronx
# 6128  New York : Region 4 Tri-Borough - The Bronx
#
#                                      presented_problems  \
# 4184  aggression (physical, verbal, property destruc...
# 9508                               leaving unexpectedly
# 6128                                    self-injurious
#
#      state_presenting_problems    region_new_presenting_problems Local ID  \
# 4184            north carolina                              west  193580W
# 9508                  new york  region 4 tri-borough - the bronx   372403
# 6128                  new york  region 4 tri-borough - the bronx   285266
#
#                               Region_demographics       County  \
# 4184                        North Carolina : West  Mecklenburg
# 9508  New York : Region 4 Tri-Borough - The Bronx        Bronx
# 6128  New York : Region 4 Tri-Borough - The Bronx        Bronx
#
#         Start Coordinator  ... Employment Status at Enrollment  \
# 4184          Hunter Ross  ...                         Student
# 9508  Danielle Seivwright  ...          Day/vocational program
# 6128         Monica Yepes  ...                         Student
#
#      Grade In School      Current IEP Current 504 Plan  \
# 4184         Grade 9  Yes: 2019-09-29               No
# 9508             NaN               No               No
# 6128       Graduated  Yes: 2019-09-01              Yes
#
#                   School Setting                     Custody Status  \
# 4184          Separate classroom  Child protective services custody
# 9508                         NaN                                NaN
# 6128  Special school-in district                   Parental custody
#
#        Child Lives With state_demographics           region_new_demographics  \
# 4184  Residential staff     north carolina                              west
# 9508                NaN           new york  region 4 tri-borough - the bronx
# 6128            Parents           new york  region 4 tri-borough - the bronx
#
#      _merge
# 4184   both
# 9508   both
# 6128   both
#
# [3 rows x 57 columns]
# (17808, 57)

# %% [markdown]
# Using the `Date Enrolled in START` variable in the merged data frame, we will make a binary classifier of whether or not the client enrolled pre or post COVID. We will use March 01, 2020 as the cutoff date.

# %%
# convert to datetime format and save in enrollment_date
demographics_problems_merged['enrollment_date'] = pd.to_datetime(demographics_problems_merged['Date Enrolled in START'])
print(f"Data type for the date variable: {demographics_problems_merged['enrollment_date'].dtype}")

# create a binary clarity column based on pre and post covid.
date_cutoff = pd.to_datetime("2020-03-01")
demographics_problems_merged['is_post_covid'] = demographics_problems_merged['enrollment_date'] >= date_cutoff

# check the value counts to see how many of the inputs are post covid
demographics_problems_merged['is_post_covid'].value_counts()
# Out:
# Data type for the date variable: datetime64[ns]
# False    14270
# True      3538
# Name: is_post_covid, dtype: int64

# %%
# Check the range of the data frame
demographics_problems_merged['enrollment_date'].max()
demographics_problems_merged['enrollment_date'].min()
# Out:
# Timestamp('2020-12-30 00:00:00')
# Timestamp('2009-09-15 00:00:00')

# %%
# creating enrollment year variable to see cases by year
demographics_problems_merged['enrollment_year'] = pd.DatetimeIndex(demographics_problems_merged['enrollment_date']).year
demographics_problems_merged['enrollment_year'].value_counts()
# Out:
# 2019    4763
# 2020    4373
# 2018    3792
# 2017    2405
# 2016     950
# 2014     607
# 2015     501
# 2013     180
# 2011     114
# 2012      92
# 2010      26
# 2009       5
# Name: enrollment_year, dtype: int64

# %% [markdown]
# Save the cleaned data in a `pkl` file

# %%
# export the datasets to pickle files
pd.to_pickle(demographics_problems_merged, '../output/demographics_problems_merged.pkl')
pd.to_pickle(living_situation_change, '../output/living_situation_change.pkl')
pd.to_pickle(in_patient_admissions, '../output/in_patient_admissions.pkl')
pd.to_pickle(emergency_crisis_services, '../output/emergency_crisis_services.pkl')
pd.to_pickle(presenting_problems, '../output/presenting_problems.pkl')

# %% [markdown]
# # Preliminary data analysis

# %% [markdown]
# Load the datasets we exported earlier.

# %%
# import the datasets from pickle files
demographics_problems_merged = pd.read_pickle('../output/demographics_problems_merged.pkl')
living_situation_change = pd.read_pickle('../output/living_situation_change.pkl')
in_patient_admissions = pd.read_pickle('../output/in_patient_admissions.pkl')
emergency_crisis_services = pd.read_pickle('../output/emergency_crisis_services.pkl')
presenting_problems = pd.read_pickle('../output/presenting_problems.pkl')

# %% [markdown]
# The initial classifier seems to have way more data for the pre-covid data. So for a reasonable comparison, we will subset the data frame to an equal number of month pre and post covid start date.

# %%
# Create the lower and upper bound of the dataset
def compare_disparities(df: pd.DataFrame, month_bandwidth: int):
    pre_change_lower_bound = date_cutoff - relativedelta(months = month_bandwidth)
    post_change_upper_bound = date_cutoff + relativedelta(months = month_bandwidth)
    print(f"Pre Change Lower Bound: {pre_change_lower_bound}, Post Change Upper Bound: {post_change_upper_bound}")

    # Subset to data that is within the range of the pre and post covid data
    filtered_combined = df[(df['enrollment_date'] >= pre_change_lower_bound) &
                                                    (df['enrollment_date'] <= post_change_upper_bound)].copy()

    print(f"The shape for the filtered data frame is {filtered_combined.shape}")

    filtered_combined['is_post_covid'] = df['enrollment_date'] >= date_cutoff

    return filtered_combined

# %%
# check the value counts to see how many of the inputs are post covid
filtered_combined_10 = compare_disparities(demographics_problems_merged, 10)
filtered_combined_10['is_post_covid'].value_counts()
# Out:
# Pre Change Lower Bound: 2019-05-01 00:00:00, Post Change Upper Bound: 2021-01-01 00:00:00
# The shape for the filtered data frame is (7697, 60)
# False    4159
# True     3538
# Name: is_post_covid, dtype: int64

# %%
def count_distribution(combined: pd.DataFrame):
    # see how the frequency of presented problem changed pre and post covid
    df = pd.DataFrame(combined.groupby('is_post_covid').agg({'presented_problems' : 'value_counts'}).
                    rename(columns={'presented_problems' : 'presented_problems_count'}))

    # pivot the table to get the counts of presented problems pre and post covid
    return pd.pivot_table(df, index='is_post_covid', columns='presented_problems')

count_distribution(filtered_combined_10)

print()
# since the number entries for each presented problem before and post covid is different, 
# we need to normalize the value counts
def count_proportion(combined: pd.DataFrame):
    df = pd.DataFrame(combined.groupby('is_post_covid').agg({'presented_problems' : 'value_counts'}).
                rename(columns={'presented_problems' : 'presented_problems_count'}))
    
    df['presented_problems_count'] = (df['presented_problems_count']/df['presented_problems_count'].sum())*100

    return pd.pivot_table(df, index='is_post_covid', columns='presented_problems')

count_proportion(filtered_combined_10)
# Out:
#                                                        presented_problems_count  \
# presented_problems aggression (physical, verbal, property destruction, threats)
# is_post_covid
# False                                                             975
# True                                                              796
#
#                                                 \
# presented_problems at risk of losing placement
# is_post_covid
# False                                      235
# True                                       176
#
#                                                                           \
# presented_problems decrease in ability to participate in daily functions
# is_post_covid
# False                                                             337
# True                                                              258
#
#                                                             \
# presented_problems diagnosis and treatment plan assistance
# is_post_covid
# False                                                  309
# True                                                   289
#
#                                                                  \
# presented_problems family needs assistance leaving unexpectedly
# is_post_covid
# False                                  640                  296
# True                                   575                  245
#
#                                                                                \
# presented_problems mental health symptoms self-injurious  sexualized behavior
# is_post_covid
# False                                 568             367                 163
# True                                  502             325                 122
#
#
# presented_problems suicidal action suicidal ideation transition from hospital
# is_post_covid
# False                            2               183                       84
# True                             9               156                       85
#                                                        presented_problems_count  \
# presented_problems aggression (physical, verbal, property destruction, threats)
# is_post_covid
# False                                                       12.667273
# True                                                        10.341692
#
#                                                 \
# presented_problems at risk of losing placement
# is_post_covid
# False                                 3.053138
# True                                  2.286605
#
#                                                                           \
# presented_problems decrease in ability to participate in daily functions
# is_post_covid
# False                                                        4.378329
# True                                                         3.351955
#
#                                                             \
# presented_problems diagnosis and treatment plan assistance
# is_post_covid
# False                                             4.014551
# True                                              3.754710
#
#                                                                  \
# presented_problems family needs assistance leaving unexpectedly
# is_post_covid
# False                             8.314928             3.845654
# True                              7.470443             3.183058
#
#                                                                                \
# presented_problems mental health symptoms self-injurious  sexualized behavior
# is_post_covid
# False                            7.379499        4.768091            2.117708
# True                             6.522022        4.222424            1.585033
#
#
# presented_problems suicidal action suicidal ideation transition from hospital
# is_post_covid
# False                     0.025984          2.377550                 1.091334
# True                      0.116929          2.026764                 1.104326

# %%
# see all the unique presented problems 
filtered_combined_10.presented_problems.unique()
# Out:
# array(['aggression (physical, verbal, property destruction, threats)',
#        'decrease in ability to participate in daily functions',
#        'at risk of losing placement', 'family needs assistance',
#        'diagnosis and treatment plan assistance',
#        'mental health symptoms', 'self-injurious ',
#        'leaving unexpectedly', 'sexualized behavior', 'suicidal ideation',
#        'transition from hospital', 'suicidal action'], dtype=object)

# %%
demographics_problems_merged.state_demographics.value_counts()
# Out:
# new york          9290
# north carolina    3288
# new hampshire     1820
# california        1367
# texas             1239
# iowa               706
# colorado            98
# Name: state_demographics, dtype: int64

# %%
# creating new year variable to use groupby
filtered_combined_10['enrollment_year'] = pd.DatetimeIndex(filtered_combined_10['enrollment_date']).year
filtered_combined_10['enrollment_year'].value_counts()

# function to find distribution of problems by year
def count_year_distribution(combined: pd.DataFrame):
    # see how number of presented problems changed per year
    df = pd.DataFrame(combined.groupby('enrollment_year').agg({'presented_problems' : 'value_counts'}).
                    rename(columns={'presented_problems' : 'presented_problems_count'}))

    # pivot the table to get the counts of presented problems per year
    return pd.pivot_table(df, index='enrollment_year', columns='presented_problems')

count_year_distribution(filtered_combined_10)

# function to find proportion of problems by year
def count_year_proportion(combined: pd.DataFrame):
    # see how proportion of presented problems changed per year
    df = pd.DataFrame(combined.groupby('enrollment_year').agg({'presented_problems' : 'value_counts'}).
                rename(columns={'presented_problems' : 'presented_problems_count'}))
    
    df['presented_problems_count'] = (df['presented_problems_count']/df['presented_problems_count'].sum())*100

    # pivot the table to get the proportions of presented problems per year
    return pd.pivot_table(df, index='enrollment_year', columns='presented_problems')

count_year_proportion(filtered_combined_10)
# Out:
# 2020    4373
# 2019    3324
# Name: enrollment_year, dtype: int64
#                                                        presented_problems_count  \
# presented_problems aggression (physical, verbal, property destruction, threats)
# enrollment_year
# 2019                                                              788
# 2020                                                              983
#
#                                                 \
# presented_problems at risk of losing placement
# enrollment_year
# 2019                                       198
# 2020                                       213
#
#                                                                           \
# presented_problems decrease in ability to participate in daily functions
# enrollment_year
# 2019                                                              262
# 2020                                                              333
#
#                                                             \
# presented_problems diagnosis and treatment plan assistance
# enrollment_year
# 2019                                                   247
# 2020                                                   351
#
#                                                                  \
# presented_problems family needs assistance leaving unexpectedly
# enrollment_year
# 2019                                   515                  239
# 2020                                   700                  302
#
#                                                                                \
# presented_problems mental health symptoms self-injurious  sexualized behavior
# enrollment_year
# 2019                                  444             290                 127
# 2020                                  626             402                 158
#
#
# presented_problems suicidal action suicidal ideation transition from hospital
# enrollment_year
# 2019                             1               145                       68
# 2020                            10               194                      101
#                                                        presented_problems_count  \
# presented_problems aggression (physical, verbal, property destruction, threats)
# enrollment_year
# 2019                                                        10.237755
# 2020                                                        12.771210
#
#                                                 \
# presented_problems at risk of losing placement
# enrollment_year
# 2019                                  2.572431
# 2020                                  2.767312
#
#                                                                           \
# presented_problems decrease in ability to participate in daily functions
# enrollment_year
# 2019                                                         3.403924
# 2020                                                         4.326361
#
#                                                             \
# presented_problems diagnosis and treatment plan assistance
# enrollment_year
# 2019                                              3.209042
# 2020                                              4.560218
#
#                                                                  \
# presented_problems family needs assistance leaving unexpectedly
# enrollment_year
# 2019                              6.690919             3.105106
# 2020                              9.094452             3.923607
#
#                                                                                \
# presented_problems mental health symptoms self-injurious  sexualized behavior
# enrollment_year
# 2019                             5.768481        3.767702            1.649994
# 2020                             8.133039        5.222814            2.052748
#
#
# presented_problems suicidal action suicidal ideation transition from hospital
# enrollment_year
# 2019                      0.012992          1.883851                 0.883461
# 2020                      0.129921          2.520463                 1.312200

# %%
# checking number of data in each
filtered_combined_10.enrollment_year.value_counts()
# Out:
# 2020    4373
# 2019    3324
# Name: enrollment_year, dtype: int64

# %%
# filtering by 3 months before and after to see immediate impact
filtered_combined_3 = compare_disparities(demographics_problems_merged, 3)
filtered_combined_3['is_post_covid'].value_counts()
# Out:
# Pre Change Lower Bound: 2019-12-01 00:00:00, Post Change Upper Bound: 2020-06-01 00:00:00
# The shape for the filtered data frame is (2313, 60)
# False    1237
# True     1076
# Name: is_post_covid, dtype: int64

# %%
# running analysis based on 3 months before and after
count_distribution(filtered_combined_3)
count_proportion(filtered_combined_3)
# Out:
#                                                        presented_problems_count  \
# presented_problems aggression (physical, verbal, property destruction, threats)
# is_post_covid
# False                                                           278.0
# True                                                            257.0
#
#                                                 \
# presented_problems at risk of losing placement
# is_post_covid
# False                                     61.0
# True                                      53.0
#
#                                                                           \
# presented_problems decrease in ability to participate in daily functions
# is_post_covid
# False                                                           104.0
# True                                                             83.0
#
#                                                             \
# presented_problems diagnosis and treatment plan assistance
# is_post_covid
# False                                                 99.0
# True                                                  85.0
#
#                                                                  \
# presented_problems family needs assistance leaving unexpectedly
# is_post_covid
# False                                182.0                 81.0
# True                                 170.0                 79.0
#
#                                                                                \
# presented_problems mental health symptoms self-injurious  sexualized behavior
# is_post_covid
# False                               184.0           115.0                50.0
# True                                160.0            98.0                32.0
#
#
# presented_problems suicidal action suicidal ideation transition from hospital
# is_post_covid
# False                          1.0              60.0                     22.0
# True                           NaN              41.0                     18.0
#                                                        presented_problems_count  \
# presented_problems aggression (physical, verbal, property destruction, threats)
# is_post_covid
# False                                                       12.019023
# True                                                        11.111111
#
#                                                 \
# presented_problems at risk of losing placement
# is_post_covid
# False                                 2.637268
# True                                  2.291396
#
#                                                                           \
# presented_problems decrease in ability to participate in daily functions
# is_post_covid
# False                                                        4.496325
# True                                                         3.588413
#
#                                                             \
# presented_problems diagnosis and treatment plan assistance
# is_post_covid
# False                                             4.280156
# True                                              3.674881
#
#                                                                  \
# presented_problems family needs assistance leaving unexpectedly
# is_post_covid
# False                             7.868569             3.501946
# True                              7.349762             3.415478
#
#                                                                                \
# presented_problems mental health symptoms self-injurious  sexualized behavior
# is_post_covid
# False                            7.955037        4.971898            2.161695
# True                             6.917423        4.236922            1.383485
#
#
# presented_problems suicidal action suicidal ideation transition from hospital
# is_post_covid
# False                     0.043234          2.594034                 0.951146
# True                           NaN          1.772590                 0.778210

# %%
filtered_combined_3.presented_problems.unique()
# Out:
# array(['aggression (physical, verbal, property destruction, threats)',
#        'decrease in ability to participate in daily functions',
#        'family needs assistance', 'leaving unexpectedly',
#        'mental health symptoms', 'self-injurious ',
#        'diagnosis and treatment plan assistance', 'suicidal ideation',
#        'at risk of losing placement', 'sexualized behavior',
#        'transition from hospital', 'suicidal action'], dtype=object)

# %%
# count presenting problems by year
count_year_distribution(demographics_problems_merged)
count_year_proportion(demographics_problems_merged)
# Out:
#                                                        presented_problems_count  \
# presented_problems aggression (physical, verbal, property destruction, threats)
# enrollment_year
# 2009                                                              1.0
# 2010                                                              5.0
# 2011                                                             22.0
# 2012                                                             16.0
# 2013                                                             38.0
# 2014                                                            175.0
# 2015                                                            143.0
# 2016                                                            243.0
# 2017                                                            578.0
# 2018                                                            922.0
# 2019                                                           1136.0
# 2020                                                            983.0
#
#                                                 \
# presented_problems at risk of losing placement
# enrollment_year
# 2009                                       NaN
# 2010                                       3.0
# 2011                                      15.0
# 2012                                      10.0
# 2013                                      19.0
# 2014                                      39.0
# 2015                                      39.0
# 2016                                      57.0
# 2017                                     150.0
# 2018                                     187.0
# 2019                                     267.0
# 2020                                     213.0
#
#                                                                           \
# presented_problems decrease in ability to participate in daily functions
# enrollment_year
# 2009                                                              1.0
# 2010                                                              2.0
# 2011                                                              7.0
# 2012                                                             10.0
# 2013                                                             17.0
# 2014                                                             32.0
# 2015                                                             33.0
# 2016                                                             53.0
# 2017                                                            164.0
# 2018                                                            300.0
# 2019                                                            392.0
# 2020                                                            333.0
#
#                                                             \
# presented_problems diagnosis and treatment plan assistance
# enrollment_year
# 2009                                                   1.0
# 2010                                                   5.0
# 2011                                                  14.0
# 2012                                                  16.0
# 2013                                                  21.0
# 2014                                                  33.0
# 2015                                                  32.0
# 2016                                                  41.0
# 2017                                                 158.0
# 2018                                                 293.0
# 2019                                                 353.0
# 2020                                                 351.0
#
#                                                                  \
# presented_problems family needs assistance leaving unexpectedly
# enrollment_year
# 2009                                   NaN                  NaN
# 2010                                   2.0                  NaN
# 2011                                   9.0                  NaN
# 2012                                   8.0                  1.0
# 2013                                  13.0                  2.0
# 2014                                  61.0                 18.0
# 2015                                  56.0                 22.0
# 2016                                 134.0                 74.0
# 2017                                 363.0                168.0
# 2018                                 656.0                272.0
# 2019                                 755.0                318.0
# 2020                                 700.0                302.0
#
#                                                                                \
# presented_problems mental health symptoms self-injurious  sexualized behavior
# enrollment_year
# 2009                                  1.0             1.0                 NaN
# 2010                                  5.0             2.0                 NaN
# 2011                                 22.0            12.0                 1.0
# 2012                                 15.0             9.0                 2.0
# 2013                                 29.0            17.0                 NaN
# 2014                                111.0            58.0                14.0
# 2015                                 74.0            48.0                16.0
# 2016                                138.0            98.0                35.0
# 2017                                338.0           198.0                99.0
# 2018                                503.0           313.0               136.0
# 2019                                653.0           416.0               167.0
# 2020                                626.0           402.0               158.0
#
#
# presented_problems suicidal action suicidal ideation transition from hospital
# enrollment_year
# 2009                           NaN               NaN                      NaN
# 2010                           NaN               1.0                      1.0
# 2011                           NaN               8.0                      4.0
# 2012                           NaN               3.0                      2.0
# 2013                           NaN              15.0                      9.0
# 2014                           NaN              53.0                     13.0
# 2015                           NaN              27.0                     11.0
# 2016                           NaN              49.0                     28.0
# 2017                           NaN             106.0                     83.0
# 2018                           2.0             133.0                     75.0
# 2019                           1.0             198.0                    107.0
# 2020                          10.0             194.0                    101.0
#                                                        presented_problems_count  \
# presented_problems aggression (physical, verbal, property destruction, threats)
# enrollment_year
# 2009                                                         0.005615
# 2010                                                         0.028077
# 2011                                                         0.123540
# 2012                                                         0.089847
# 2013                                                         0.213387
# 2014                                                         0.982704
# 2015                                                         0.803010
# 2016                                                         1.364555
# 2017                                                         3.245732
# 2018                                                         5.177448
# 2019                                                         6.379155
# 2020                                                         5.519991
#
#                                                 \
# presented_problems at risk of losing placement
# enrollment_year
# 2009                                       NaN
# 2010                                  0.016846
# 2011                                  0.084232
# 2012                                  0.056155
# 2013                                  0.106694
# 2014                                  0.219003
# 2015                                  0.219003
# 2016                                  0.320081
# 2017                                  0.842318
# 2018                                  1.050090
# 2019                                  1.499326
# 2020                                  1.196092
#
#                                                                           \
# presented_problems decrease in ability to participate in daily functions
# enrollment_year
# 2009                                                         0.005615
# 2010                                                         0.011231
# 2011                                                         0.039308
# 2012                                                         0.056155
# 2013                                                         0.095463
# 2014                                                         0.179695
# 2015                                                         0.185310
# 2016                                                         0.297619
# 2017                                                         0.920934
# 2018                                                         1.684636
# 2019                                                         2.201258
# 2020                                                         1.869946
#
#                                                             \
# presented_problems diagnosis and treatment plan assistance
# enrollment_year
# 2009                                              0.005615
# 2010                                              0.028077
# 2011                                              0.078616
# 2012                                              0.089847
# 2013                                              0.117925
# 2014                                              0.185310
# 2015                                              0.179695
# 2016                                              0.230234
# 2017                                              0.887242
# 2018                                              1.645328
# 2019                                              1.982255
# 2020                                              1.971024
#
#                                                                  \
# presented_problems family needs assistance leaving unexpectedly
# enrollment_year
# 2009                                   NaN                  NaN
# 2010                              0.011231                  NaN
# 2011                              0.050539                  NaN
# 2012                              0.044924             0.005615
# 2013                              0.073001             0.011231
# 2014                              0.342543             0.101078
# 2015                              0.314465             0.123540
# 2016                              0.752471             0.415544
# 2017                              2.038410             0.943396
# 2018                              3.683738             1.527403
# 2019                              4.239668             1.785714
# 2020                              3.930818             1.695867
#
#                                                                                \
# presented_problems mental health symptoms self-injurious  sexualized behavior
# enrollment_year
# 2009                             0.005615        0.005615                 NaN
# 2010                             0.028077        0.011231                 NaN
# 2011                             0.123540        0.067385            0.005615
# 2012                             0.084232        0.050539            0.011231
# 2013                             0.162848        0.095463                 NaN
# 2014                             0.623315        0.325696            0.078616
# 2015                             0.415544        0.269542            0.089847
# 2016                             0.774933        0.550314            0.196541
# 2017                             1.898023        1.111860            0.555930
# 2018                             2.824573        1.757637            0.763702
# 2019                             3.666891        2.336029            0.937781
# 2020                             3.515274        2.257412            0.887242
#
#
# presented_problems suicidal action suicidal ideation transition from hospital
# enrollment_year
# 2009                           NaN               NaN                      NaN
# 2010                           NaN          0.005615                 0.005615
# 2011                           NaN          0.044924                 0.022462
# 2012                           NaN          0.016846                 0.011231
# 2013                           NaN          0.084232                 0.050539
# 2014                           NaN          0.297619                 0.073001
# 2015                           NaN          0.151617                 0.061770
# 2016                           NaN          0.275157                 0.157233
# 2017                           NaN          0.595238                 0.466083
# 2018                      0.011231          0.746855                 0.421159
# 2019                      0.005615          1.111860                 0.600854
# 2020                      0.056155          1.089398                 0.567161

# %%
demographics_problems_merged.enrollment_year.value_counts()
# Out:
# 2019    4763
# 2020    4373
# 2018    3792
# 2017    2405
# 2016     950
# 2014     607
# 2015     501
# 2013     180
# 2011     114
# 2012      92
# 2010      26
# 2009       5
# Name: enrollment_year, dtype: int64

# %%
count_year_proportion(filtered_combined_10)
count_year_distribution(filtered_combined_10)
# Out:
#                                                        presented_problems_count  \
# presented_problems aggression (physical, verbal, property destruction, threats)
# enrollment_year
# 2019                                                        10.237755
# 2020                                                        12.771210
#
#                                                 \
# presented_problems at risk of losing placement
# enrollment_year
# 2019                                  2.572431
# 2020                                  2.767312
#
#                                                                           \
# presented_problems decrease in ability to participate in daily functions
# enrollment_year
# 2019                                                         3.403924
# 2020                                                         4.326361
#
#                                                             \
# presented_problems diagnosis and treatment plan assistance
# enrollment_year
# 2019                                              3.209042
# 2020                                              4.560218
#
#                                                                  \
# presented_problems family needs assistance leaving unexpectedly
# enrollment_year
# 2019                              6.690919             3.105106
# 2020                              9.094452             3.923607
#
#                                                                                \
# presented_problems mental health symptoms self-injurious  sexualized behavior
# enrollment_year
# 2019                             5.768481        3.767702            1.649994
# 2020                             8.133039        5.222814            2.052748
#
#
# presented_problems suicidal action suicidal ideation transition from hospital
# enrollment_year
# 2019                      0.012992          1.883851                 0.883461
# 2020                      0.129921          2.520463                 1.312200
#                                                        presented_problems_count  \
# presented_problems aggression (physical, verbal, property destruction, threats)
# enrollment_year
# 2019                                                              788
# 2020                                                              983
#
#                                                 \
# presented_problems at risk of losing placement
# enrollment_year
# 2019                                       198
# 2020                                       213
#
#                                                                           \
# presented_problems decrease in ability to participate in daily functions
# enrollment_year
# 2019                                                              262
# 2020                                                              333
#
#                                                             \
# presented_problems diagnosis and treatment plan assistance
# enrollment_year
# 2019                                                   247
# 2020                                                   351
#
#                                                                  \
# presented_problems family needs assistance leaving unexpectedly
# enrollment_year
# 2019                                   515                  239
# 2020                                   700                  302
#
#                                                                                \
# presented_problems mental health symptoms self-injurious  sexualized behavior
# enrollment_year
# 2019                                  444             290                 127
# 2020                                  626             402                 158
#
#
# presented_problems suicidal action suicidal ideation transition from hospital
# enrollment_year
# 2019                             1               145                       68
# 2020                            10               194                      101

# %%
filtered_combined_10.enrollment_year.value_counts()
# Out:
# 2020    4373
# 2019    3324
# Name: enrollment_year, dtype: int64

# %%
# emergency_crisis_services
# emergency_crisis_services.merge(demographics, left_on='Individual ID', right_on='Local ID',
#                                                                   how='inner', suffixes=('_emergency_services', '_demographics'), 
#                                                                   indicator = True).drop_duplicates()

# %%
living_situation_change.head()
living_situation_change.columns
living_situation_change.info()
# Out:
#   Individual ID                    Region Current Living Situation  \
# 0          6942    Texas : El Paso County               Group home
# 1       545329E     North Carolina : East               Group home
# 2       724663E     North Carolina : East    Other: crisis respite
# 3       717526C  North Carolina : Central               Group home
# 4       351430W     North Carolina : West               Group home
#
#     New Living Situation                  Primary Reason for Move  \
# 0            Family home  Other: APS report came back unconfirmed
# 1             Group home           Mental/behavioral health needs
# 2  Other: crisis respite           Mental/behavioral health needs
# 3             Group home           Mental/behavioral health needs
# 4            Family home           Mental/behavioral health needs
#
#   Date of Move              Entered By
# 0   2019-07-08         Angelica Garcia
# 1   2018-05-01  David Jerome Lewis  II
# 2   2019-06-01  David Jerome Lewis  II
# 3   2019-07-31  Brittney Peters-Barnes
# 4   2019-04-01          Aishah Bridges
# Index(['Individual ID', 'Region', 'Current Living Situation',
#        'New Living Situation', 'Primary Reason for Move', 'Date of Move',
#        'Entered By'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 601 entries, 0 to 600
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Individual ID             601 non-null    object
#  1   Region                    601 non-null    object
#  2   Current Living Situation  601 non-null    object
#  3   New Living Situation      601 non-null    object
#  4   Primary Reason for Move   601 non-null    object
#  5   Date of Move              593 non-null    datetime64[ns]
#  6   Entered By                601 non-null    object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 33.0+ KB

# %%
# rename the column
living_situation_change.rename(columns={'Primary Reason for Move': 'move_reason'}, inplace=True)

# confirm that the column was renamed successfully
living_situation_change.columns
# Out:
# Index(['Individual ID', 'Region', 'Current Living Situation',
#        'New Living Situation', 'move_reason', 'Date of Move', 'Entered By'],
#       dtype='object')

# %%
living_situation_change_no_other = living_situation_change[~living_situation_change["move_reason"].str.contains('Other:')].copy()
print(f"The number of unique move reasons before dropping 'Other' is: {living_situation_change.move_reason.nunique()}")
print(f"The number of unique move reasons is: {living_situation_change_no_other.move_reason.nunique()}")

print(f"Retention Rate After Dropping 'Other': {round(100*living_situation_change_no_other.shape[0]/living_situation_change.shape[0], 2)}%")
# Out:
# The number of unique move reasons before dropping 'Other' is: 88
# The number of unique move reasons is: 6
# Retention Rate After Dropping 'Other': 83.86%

# %%
living_situation_change_no_other['move_date'] = pd.to_datetime(living_situation_change_no_other['Date of Move'])
print(f"Data type for the date variable: {living_situation_change_no_other['move_date'].dtype}")

# create a binary clarity column based on pre and post covid.
date_cutoff = pd.to_datetime("2020-03-01")
living_situation_change_no_other['is_post_covid'] = living_situation_change_no_other['move_date'] >= date_cutoff

# check the value counts to see how many of the inputs are post covid
living_situation_change_no_other['is_post_covid'].value_counts()
# Out:
# Data type for the date variable: datetime64[ns]
# True     345
# False    159
# Name: is_post_covid, dtype: int64

# %%
# fucntion to cutoff date for living situation data
def compare_living_disparities(df: pd.DataFrame, month_bandwidth: int):
    pre_change_lower_bound = date_cutoff - relativedelta(months = month_bandwidth)
    post_change_upper_bound = date_cutoff + relativedelta(months = month_bandwidth)
    print(f"Pre Change Lower Bound: {pre_change_lower_bound}, Post Change Upper Bound: {post_change_upper_bound}")

    # Subset to data that is within the range of the pre and post covid data
    filtered_combined = df[(df['move_date'] >= pre_change_lower_bound) &
                                                    (df['move_date'] <= post_change_upper_bound)].copy()

    print(f"The shape for the filtered data frame is {filtered_combined.shape}")

    filtered_combined['is_post_covid'] = df['move_date'] >= date_cutoff

    return filtered_combined

filtered_living_12 = compare_living_disparities(living_situation_change_no_other, 12)
filtered_living_12['is_post_covid'].value_counts()
# Out:
# Pre Change Lower Bound: 2019-03-01 00:00:00, Post Change Upper Bound: 2021-03-01 00:00:00
# The shape for the filtered data frame is (334, 9)
# True     199
# False    135
# Name: is_post_covid, dtype: int64

# %%
def count_living_distribution(combined: pd.DataFrame):
    # see how the frequency of presented problem changed pre and post covid
    df = pd.DataFrame(combined.groupby('is_post_covid').agg({'move_reason' : 'value_counts'}).
                    rename(columns={'move_reason' : 'move_reason_count'}))

    # pivot the table to get the counts of presented problems pre and post covid
    return pd.pivot_table(df, index='is_post_covid', columns='move_reason')

count_living_distribution(filtered_living_12)

print()
# since the number entries for each presented problem before and post covid is different, 
# we need to normalize the value counts
def count_living_proportion(combined: pd.DataFrame):
    df = pd.DataFrame(combined.groupby('is_post_covid').agg({'move_reason' : 'value_counts'}).
                rename(columns={'move_reason' : 'move_reason_count'}))
    
    df['move_reason_count'] = (df['move_reason_count']/df['move_reason_count'].sum())*100

    return pd.pivot_table(df, index='is_post_covid', columns='move_reason')

count_living_proportion(filtered_living_12)
# Out:
#                           move_reason_count                                 \
# move_reason   Aged out of current placement Change in family circumstances
# is_post_covid
# False                                     3                              8
# True                                      1                             11
#
#                                                           \
# move_reason   Individual/family preference Medical needs
# is_post_covid
# False                                   22             1
# True                                    61             3
#
#                                               \
# move_reason   Mental/behavioral health needs
# is_post_covid
# False                                     90
# True                                     100
#
#
# move_reason   Provider change (unrelated to individual)
# is_post_covid
# False                                                11
# True                                                 23
#                           move_reason_count                                 \
# move_reason   Aged out of current placement Change in family circumstances
# is_post_covid
# False                              0.898204                       2.395210
# True                               0.299401                       3.293413
#
#                                                           \
# move_reason   Individual/family preference Medical needs
# is_post_covid
# False                             6.586826      0.299401
# True                             18.263473      0.898204
#
#                                               \
# move_reason   Mental/behavioral health needs
# is_post_covid
# False                              26.946108
# True                               29.940120
#
#
# move_reason   Provider change (unrelated to individual)
# is_post_covid
# False                                          3.293413
# True                                           6.886228

# %%
in_patient_admissions.head()
in_patient_admissions.columns
in_patient_admissions.info()
# Out:
#   Individual ID                    Region Date/Time of contact or admission  \
# 0       603802W     North Carolina : West               2015-05-01 00:00:00
# 1       1187009    Texas : Tarrant County               2016-06-16 00:00:00
# 2       1187009    Texas : Tarrant County               2016-08-31 00:00:00
# 3       421925C  North Carolina : Central               2016-11-10 10:00:00
# 4       1024977    Texas : Tarrant County               2016-06-01 18:00:00
#
#                                    Type of admission  \
# 0                         State psychiatric hospital
# 1            Community mental health in-patient unit
# 2            Community mental health in-patient unit
# 3  State operated/private ICF/DD or other I/DD fa...
# 4            Community mental health in-patient unit
#
#              Primary Reason for Contact or Admission  Length of Stay  \
# 0  Aggression (physical, verbal, property destruc...           67680
# 1  Aggression (physical, verbal, property destruc...           10080
# 2  Aggression (physical, verbal, property destruc...           10080
# 3  Aggression (physical, verbal, property destruc...           54720
# 4  Aggression (physical, verbal, property destruc...           28800
#
#   Facilitated by START Coordinator or START Team member
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
# Index(['Individual ID', 'Region', 'Date/Time of contact or admission',
#        'Type of admission', 'Primary Reason for Contact or Admission',
#        'Length of Stay',
#        'Facilitated by START Coordinator or START Team member'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2028 entries, 0 to 2027
# Data columns (total 7 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Individual ID                                          2028 non-null   object
#  1   Region                                                 2028 non-null   object
#  2   Date/Time of contact or admission                      2028 non-null   datetime64[ns]
#  3   Type of admission                                      1979 non-null   object
#  4   Primary Reason for Contact or Admission                1979 non-null   object
#  5   Length of Stay                                         2028 non-null   int64
#  6   Facilitated by START Coordinator or START Team member  1951 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 111.0+ KB

# %%
# rename the column
in_patient_admissions.rename(columns={'Primary Reason for Contact or Admission': 'admission_reason'}, inplace=True)

# confirm that the column was renamed successfully
in_patient_admissions.columns
# Out:
# Index(['Individual ID', 'Region', 'Date/Time of contact or admission',
#        'Type of admission', 'admission_reason', 'Length of Stay',
#        'Facilitated by START Coordinator or START Team member'],
#       dtype='object')

# %%
in_patient_admissions_no_other = in_patient_admissions[~in_patient_admissions["admission_reason"].str.contains('Other:', na=False)].copy()
print(f"The number of unique move reasons before dropping 'Other' is: {in_patient_admissions.admission_reason.nunique()}")
print(f"The number of unique move reasons is: {in_patient_admissions_no_other.admission_reason.nunique()}")

print(f"Retention Rate After Dropping 'Other': {round(100*in_patient_admissions_no_other.shape[0]/in_patient_admissions.shape[0], 2)}%")
# Out:
# The number of unique move reasons before dropping 'Other' is: 182
# The number of unique move reasons is: 6
# Retention Rate After Dropping 'Other': 89.0%

# %%
in_patient_admissions.admission_reason.unique()
in_patient_admissions_no_other.admission_reason.unique()
in_patient_admissions.shape
in_patient_admissions_no_other.shape
# Out:
# array(['Aggression (physical, verbal, property destruction, threats)',
#        'Self-injurious', 'Suicidal ideation/behaviors',
#        'Other: stating suicidal after she reported her old friend kissed her when she did not want to be kissed.',
#        'Other: Psychosis and Aggitation', 'Other: mental health symptoms',
#        'Other: psychosis, decreased verbal interactions',
#        'Other: psychosis, aggression', 'Other: hallucinations',
#        'Other: escalated impulisivity', 'Other: MH Symptoms',
#        'Other: psychosis', 'Other: family abandonment',
#        'Other: hallucinations/delusions/paranoia', nan,
#        'Other: Aggression; 10/03/2015 MK',
#        'Other: Aggression; 09/22/2015 MK',
#        'Other: Medical and Psychiatric symptoms',
#        'Other: Court Ordered Due to sexualized behavior',
#        'Other: psychiatric decompensation/stabilization',
#        'Other: Court ordered commitment due to criminal charges',
#        'Other: sytmptomatic', 'Other: Evaluation/Possible Depression',
#        'Other: Mandy 7/7/2014', 'Other: Mental health symptoms',
#        'Other: lack of sleep',
#        'Other: left home, trying to by a gun, threatened others',
#        'Other: Hallucinations/Psychosis', 'Other: Anxiety, Paranoia',
#        'Other: intoxication, aggression',
#        'Other: Aggression; 10/01/2015; UL',
#        'Other: Aggression; 10/01/2015 UL',
#        'Other: she requested admission',
#        'Other: not feeling well on 8/22/15',
#        'Other: Hearing voices, sexualized behavior',
#        'Other: 3rd admission to hospital for aggression',
#        'Other: second admission to hospital this month for aggression',
#        'Other: Threatening to harm self and others. Experienced a Manic',
#        'Other: Threatening to harm self and others. Experienced a Manic episode',
#        'Other: Was upset after his roommate recieved a new game system',
#        'Other: psychotic decompensation/unmedicated',
#        'Other: Agressive at home mother not abel to provide supprt. No placement avaialble',
#        'Other: Acute Mania',
#        'Other: irrate and showing dangerous behaviors',
#        'Other: Extreme use of EMS services and presenting with extreme anxiety',
#        'Other: stopped taking his medications, said he did not feel right, took himself to hospital',
#        'Other: MH symptomology', 'Other: Anxiety',
#        'Other: increased mental health symptoms',
#        'Other: violence and homicidal statements',
#        'Other: Increase in depression symptoms',
#        'Other: Safety concerns, leaving home unexpectedly',
#        'Other: Not med-compliant, had not eaten in 4 days, had not showered in 2 weeks',
#        'Other: Psychosis', 'Other: Depression, Suicidal Ideation',
#        'Other: Aggression, self-injurious behavior, mental health symptoms',
#        'Other: left unexpectedly',
#        'Other: mood changes, self injurious behavior.',
#        'Other: Homeless and needed mental health services',
#        'Other: Homeless, in need of psychiatric and medical treatment',
#        'Other: Mental Health Symptoms', 'Other: Medication adjustments',
#        'Other: Decline in skills; delusions',
#        'Other: aggression, self injury, "eye rolling in back of head"',
#        'Other: symptoms of psychosis likely related to substance use',
#        'Other: Homicidal Ideations',
#        'Other: Medication non adherence, interrupted sleep pattern, non involvement in school',
#        'Other: ID MI Specialty In-patient evaluation',
#        'Other: MH symptoms', 'Other: homicidal ideation with a plan',
#        'Other: Mental health symptoms-running out in traffic; threatening to harm others',
#        'Other: Transition from hospital',
#        'Other: transfer from UMASS, significant hallucinations, functional decline',
#        'Other: review medication and aggression',
#        'Other: Out of medications, evaluation of medical concerns, e.g., UTI',
#        'Other: Decreased ability to participate in daily functions, non-med compliant',
#        'Other: medication management and monitoring',
#        'Other: No housing/homeless; Foot wound',
#        'Other: mood lability and psychosis',
#        'Other: Family needs assistance', 'Other: Possible Psychosis',
#        'Other: ECT treatment',
#        'Other: reports of suicidal ideation and requesting medication changes; also reporting ECT is not working',
#        'Other: agression towards mother',
#        'Other: medication stabilization',
#        'Other: Missing; medication non-compliant; emotionally dysregulated',
#        'Other: transitio/respite/from jail', 'Other: Medication refusal',
#        'Other: Mental Helth issues',
#        'Other: dialing 911/ontacting th police',
#        'Other: Hallucinations/delusions',
#        'Other: left home in the middle of the night',
#        'Other: Psychiatric symptoms', 'Other: Delusional',
#        'Other: Stabilization on Meds',
#        'Other: Agression-physical, property destruction. 10/29, CW',
#        'Other: psychosis and aggression', 'Other: Mania',
#        'Other: medical concerns resulting from psychiatric medications',
#        'Other: Catatonia', 'Other: med compliance',
#        'Other: Active Psychosis', 'Other: crisis',
#        'Other: mental health symptoms- severe depression',
#        'Other: Still in MHU from admission last month. Waiting to get placement.',
#        'Other: Still in MHU as he is waiting for plamcement',
#        'Other: medication adjustment/observation of depressive symptoms',
#        'Other: he stated he felt unstable',
#        'Other: felt unstable and that his meds were not working', 'Other',
#        "Other: OD'ed Took 17 Seroquel",
#        'Other: Emergency D/C from Community Provider to Marshalltown hospital- No MHU in hospital; pending placement at MHI',
#        "Other: OD'ed72 Ibuprofen",
#        "Other: Cut self, smeared blood on staff's vehicle",
#        'Other: Suicide Attempt - Advil Overdose',
#        "Other: Reports of seeing individuals others don't see",
#        'Other: Excessively Bathing', 'Other: incapable to proceed status',
#        'Other: "tantrums"', 'Other: Medical, Psychiatric symptoms',
#        'Other: unknown', 'Other: Irritability', 'Other: neglect',
#        'Other: after getting upset wtih mom ED decided to admit him',
#        'Other: Medication Review/Side Effects',
#        'Other: leaving unexpectedly and mental health symptoms',
#        'Other: Mental health symptoms, threats to harm housemates',
#        'Other: ran away from day program, hiding and discarding medication',
#        'Other: ran away from home with knife in hand that was used to get out of home through window',
#        'Other: Increased anxiety at home, parents anticipating aggression',
#        'Other: Feeling unsafe in her current environment',
#        'Other: Mental health instability',
#        'Other: Mental health instability; suicidal ideations',
#        'Medical Concerns',
#        'Other: Psycotic Symtoms- responding to internal stimuli, disorgnized thoughts',
#        'Other: Did not have access to psychiatric medications',
#        'Other: Mental health concerns',
#        'Other: Psychotic Symptoms- Hallucinations and hitting self in the face causing brusing',
#        'Other: Mental Health Committal', 'Medication Evaluation',
#        'Other: Grave Disability', 'Other: Aggresssion and COVID-19',
#        'Other: mental health', 'Other: Diagnostic clarification',
#        'Other: Diagnostic Clarification',
#        'Other: Leaving unexpectedly; mother looking for placement.',
#        'Other: Unwilling to return to host home',
#        'Other: Decline in mental health',
#        'Other: Responding to internal stimuli',
#        'Other: MH symptoms, i.e. hallucinations', 'Other: hallucination',
#        'Other: Overdose of Seroquel',
#        'Other: Safety reasons (leaving unexpectedly)',
#        'Other: Not feeling safe in the community',
#        'Other: Committal, left unexpectedly and planned to leave IA for CA',
#        'Other: MH Symptoms-hallucinations',
#        'Other: Mental Health Symtpoms; auditory hallucinations due to Lithium levels',
#        'Other: Diagnostic clarification and medication re-evaluation',
#        'Other: waiting for residential placement',
#        'Other: Phsyical/Verbal Aggression and Mental Health Symptoms',
#        'Other: disorganized, was pacing fast in circles, and "in his own world"',
#        "Other: declining medications, medical and psychiatric appointments as outlined in his outpatient's committal",
#        'Other: mental health symptoms/onset of auditory hallucinations',
#        'Other: family not ready for his return home- requesting in home services to be put in place',
#        'Other: further stabilization',
#        'Other: Medical/Mental health symptoms',
#        'Other: Command hallucinations',
#        'Other: Mental Health symptoms following medical in-patient admission',
#        'Other: medical evaluations and concerns related to catatonia',
#        'Other: Feeling Unsafe in new home',
#        'Other: mood symptoms and dangerous behavior demonstrated',
#        'Other: Mental health concerns, worsening psychiatric hallucinations, concerns of family',
#        'Other: 72 hold',
#        'Other: Auditory hallucinations, suicidal gestures, fixed false beliefs',
#        'Other: further stabilization and facilitation of in home services',
#        'Other: Mental Health Symptoms/Feeling Unsafe in Home',
#        'Other: Illegal substance abuse',
#        'Other: Taken by law enforcement after attempting to break into a San Jose State University building',
#        'Other: treatment support and medication management',
#        'Other: Left Unexpectedly',
#        'Other: California Hospital Medical Medical Center - 5150',
#        'Other: Taken to California Hospital 5150 Was parked outside of 711 in handicapped w/o a plaque spot but his mom left the car and the police came to car and told him to move the car but he cannot drive and became frustrated and eventually got naked and ran around',
#        'Other: Loss of placement'], dtype=object)
# array(['Aggression (physical, verbal, property destruction, threats)',
#        'Self-injurious', 'Suicidal ideation/behaviors', nan, 'Other',
#        'Medical Concerns', 'Medication Evaluation'], dtype=object)
# (2028, 7)
# (1805, 7)

# %%
in_patient_admissions_no_other['admission_date'] = pd.to_datetime(in_patient_admissions_no_other['Date/Time of contact or admission'])
print(f"Data type for the date variable: {in_patient_admissions_no_other['admission_date'].dtype}")

# create a binary clarity column based on pre and post covid.
date_cutoff = pd.to_datetime("2020-03-01")
in_patient_admissions_no_other['is_post_covid'] = in_patient_admissions_no_other['admission_date'] >= date_cutoff

# check the value counts to see how many of the inputs are post covid
in_patient_admissions_no_other['is_post_covid'].value_counts()
# Out:
# Data type for the date variable: datetime64[ns]
# False    1280
# True      525
# Name: is_post_covid, dtype: int64

# %%
def compare_admission_disparities(df: pd.DataFrame, month_bandwidth: int):
    pre_change_lower_bound = date_cutoff - relativedelta(months = month_bandwidth)
    post_change_upper_bound = date_cutoff + relativedelta(months = month_bandwidth)
    print(f"Pre Change Lower Bound: {pre_change_lower_bound}, Post Change Upper Bound: {post_change_upper_bound}")

    # Subset to data that is within the range of the pre and post covid data
    filtered_combined = df[(df['admission_date'] >= pre_change_lower_bound) &
                                                    (df['admission_date'] <= post_change_upper_bound)].copy()

    print(f"The shape for the filtered data frame is {filtered_combined.shape}")

    filtered_combined['is_post_covid'] = df['admission_date'] >= date_cutoff

    return filtered_combined

filtered_admission_10 = compare_admission_disparities(in_patient_admissions_no_other, 10)
filtered_admission_10['is_post_covid'].value_counts()
# Out:
# Pre Change Lower Bound: 2019-05-01 00:00:00, Post Change Upper Bound: 2021-01-01 00:00:00
# The shape for the filtered data frame is (531, 9)
# True     279
# False    252
# Name: is_post_covid, dtype: int64

# %%
def count_admissions_distribution(combined: pd.DataFrame):
    # see how the frequency of admission reasons changed pre and post covid
    df = pd.DataFrame(combined.groupby('is_post_covid').agg({'admission_reason' : 'value_counts'}).
                    rename(columns={'admission_reason' : 'move_reason_count'}))

    # pivot the table to get the counts of presented problems pre and post covid
    return pd.pivot_table(df, index='is_post_covid', columns='admission_reason')

count_admissions_distribution(filtered_admission_10)

# proportion for admission reasons comparing pre and post covid
def count_admissions_proportion(combined: pd.DataFrame):
    df = pd.DataFrame(combined.groupby('is_post_covid').agg({'admission_reason' : 'value_counts'}).
                rename(columns={'admission_reason' : 'admission_reason_count'}))
    
    df['admission_reason_count'] = (df['admission_reason_count']/df['admission_reason_count'].sum())*100

    return pd.pivot_table(df, index='is_post_covid', columns='admission_reason')

count_admissions_proportion(filtered_admission_10)
# Out:
#                                                             move_reason_count  \
# admission_reason Aggression (physical, verbal, property destruction, threats)
# is_post_covid
# False                                                         155.0
# True                                                          158.0
#
#                                                                               \
# admission_reason Medical Concerns Medication Evaluation Other Self-injurious
# is_post_covid
# False                         4.0                   1.0   1.0           22.0
# True                          6.0                   8.0   NaN           24.0
#
#
# admission_reason Suicidal ideation/behaviors
# is_post_covid
# False                                   67.0
# True                                    81.0
#                                                        admission_reason_count  \
# admission_reason Aggression (physical, verbal, property destruction, threats)
# is_post_covid
# False                                                     29.411765
# True                                                      29.981025
#
#                                                                    \
# admission_reason Medical Concerns Medication Evaluation     Other
# is_post_covid
# False                    0.759013              0.189753  0.189753
# True                     1.138520              1.518027       NaN
#
#
# admission_reason Self-injurious Suicidal ideation/behaviors
# is_post_covid
# False                  4.174573                   12.713472
# True                   4.554080                   15.370019

# %%
# create a function to make a custom bar plot
def make_custom_bar_plot(df, bar_x, bar_y, fill_by, x_label, y_label, title, file_name):
    plot1 = (ggplot(df, aes(x = bar_x, y = bar_y, fill= fill_by))
            + geom_col()
            + coord_flip()
            + labs(x = x_label, y = y_label, title = title)
            + theme_light()
            + theme(legend_position='none'))

    ggsave(plot=plot1, filename = file_name, path = '../output/figures/', dpi  = 500)

    return plot1

# %%
presenting_problems_count_df = pd.DataFrame(demographics_problems_merged.presented_problems.value_counts()).reset_index().rename(
    columns={'index' : 'problem', 'presented_problems' : 'frequency'})
make_custom_bar_plot(df = presenting_problems_count_df, bar_x = 'problem', bar_y = 'frequency', fill_by ='problem', 
                     x_label = 'Presented Problems', y_label = 'Frequency', title='Frequency of Presented Problems', file_name = 'presenting_problems_count.png')
# Out:
# /Users/aimen/opt/anaconda3/lib/python3.9/site-packages/plotnine/ggplot.py:718: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /Users/aimen/opt/anaconda3/lib/python3.9/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Filename: ../output/figures/presenting_problems_count.png
# <ggplot: (8777951505065)>

# %%
living_condition_no_other = demographics_problems_merged[~demographics_problems_merged['Current living situation at enrollment to START'].str.contains('Other:')].copy()

living_condition_df = pd.DataFrame(living_condition_no_other['Current living situation at enrollment to START'].value_counts()).reset_index().rename(
    columns={'index' : 'living_condition', 'Current living situation at enrollment to START' : 'frequency'})
living_condition_df['frequency_percentile'] = (living_condition_df['frequency']/living_condition_df['frequency'].sum())*100

make_custom_bar_plot(df = living_condition_df, bar_x = 'living_condition', bar_y = 'frequency_percentile', fill_by = 'living_condition', 
                     x_label = 'Living Condition', y_label = 'Percentile', title='Living Condition of START participant at Enrollment', 
                     file_name = 'living_condition_at_enrollment.png')
# Out:
# /Users/aimen/opt/anaconda3/lib/python3.9/site-packages/plotnine/ggplot.py:718: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /Users/aimen/opt/anaconda3/lib/python3.9/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Filename: ../output/figures/living_condition_at_enrollment.png
# <ggplot: (8777866391293)>

# %%
presenting_problems_count_df = pd.DataFrame(demographics_problems_merged.presented_problems.value_counts()).reset_index().rename(
    columns={'index' : 'problem', 'presented_problems' : 'frequency'})
make_custom_bar_plot(df = presenting_problems_count_df, bar_x = 'problem', bar_y = 'frequency', fill_by ='problem', 
                     x_label = 'Presented Problems', y_label = 'Frequency', title='Frequency of Presented Problems', file_name = 'presenting_problems_count.png')
# Out:
# Index(['Client Local Id', 'START Coordinator', 'Region_presenting_problems',
#        'presented_problems', 'state_presenting_problems',
#        'region_new_presenting_problems', 'Local ID', 'Region_demographics',
#        'County', 'Start Coordinator', 'Date Enrolled in START', 'Status',
#        'Status Date', 'Time Enrolled in START', 'Source of referral to START',
#        'Suitability of enrollment in START',
#        'Individual/Caregiver reliable access to technology',
#        'Presenting problems at time of enrollment', 'Services at Enrollment',
#        'Date of birth', 'Gender', 'Race', 'Ethnicity',
#        'Level of Intellectual Disability',
#        'Current living situation at enrollment to START',
#        'More than one living situation over the last 5 years?',
#        'More than one living situation over the last year?',
#        'Psychiatric hospitalization in past year (at enrollment to START)',
#        'Psychiatric hospitalizations in past 1 - 5 years (at enrollment to START)',
#        'Emergency department visits in past year (at enrollment to START)',
#        'Emergency department visits in past 1-5 years (at enrollment to START)',
#        'Law enforcement encounters in past year (at enrollment to START)',
#        'Law enforcement encounters in past 1 - 5 years (at enrollment to START)',
#        'Psychiatric diagnoses', 'Medical diagnoses', 'Other Disabilities',
#        'Cause/etiology of disability',
#        'Who is the individual's primary caregiver?',
#        'Does the individual have a secondary caregiver?',
#        'Does the individual have a legal guardian?', 'Funding',
#        'History of Child Protective Services involvement in past year (at enrollment to START)',
#        'History of Child Protective Services involvement in lifetime (at enrollment to START)',
#        'State sponsored ICF/DD stay in past year (at enrollment to START)',
#        'State sponsored ICF/DD stay in past 1 - 5 years (at enrollment to START)',
#        'Jailed in the past year (at enrollment to START)',
#        'Jailed in the past 1 - 5 years (at enrollment to START)',
#        'Employment Status at Enrollment', 'Grade In School', 'Current IEP',
#        'Current 504 Plan', 'School Setting', 'Custody Status',
#        'Child Lives With', 'state_demographics', 'region_new_demographics',
#        '_merge', 'enrollment_date', 'is_post_covid', 'enrollment_year'],
#       dtype='object')
